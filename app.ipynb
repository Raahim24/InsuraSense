# %%
import json
import logging
import os
import time
import asyncio
import re
from typing import Dict, List, Any, Optional, Tuple, Union
from pathlib import Path
from datetime import datetime
import traceback
import warnings

import google.generativeai as genai
from google.genai import types

import fitz
import PyPDF2

import httpx

from pydantic import BaseModel, Field, validator
from pydantic.types import constr, conint

import pathlib
import shutil
from io import BytesIO

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(name)s - %(message)s'
)
logger = logging.getLogger(__name__)

warnings.filterwarnings("ignore", category=UserWarning)

# %%
from dotenv import load_dotenv
load_dotenv()  # This loads your .env file

api_key = os.getenv('GEMINI_API_KEY')
genai.configure(api_key=api_key)

# %%
import fitz  # PyMuPDF

def extract_fields(pdf_path):
    doc = fitz.open(pdf_path)
    fields = []

    for page_num, page in enumerate(doc, start=1):
        for w in page.widgets() or []:
            is_checkbox = (w.field_type == fitz.PDF_WIDGET_TYPE_CHECKBOX)

            field = {
                "name": w.field_name,
                "type": "checkbox" if is_checkbox else "text",
                "value": w.field_value,
                "page": page_num,
                "field_type": w.field_type,
                "field_type_string": w.field_type_string,
                "field_label": w.field_label,
            }

            # Add on_state only for checkboxes
            if is_checkbox:
                try:
                    field["on_state"] = w.button_get_on_state_name()  # e.g., "Yes", "On"
                except Exception:
                    field["on_state"] = "Yes"  # safe default

            fields.append(field)

    # Group fields by page
    fields_by_page = {}
    for f in fields:
        fields_by_page.setdefault(f["page"], []).append(f)

    return fields_by_page

# %%
# Test it
abdulla_pa_fields = extract_fields("Input Data/Abdulla/PA.pdf")

# %%
abdulla_pa_fields
# Out:
# {2: [{'name': 'CB1',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 2,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Start of treatment',
#    'on_state': 'Yes'},
#   {'name': 'T2',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Start date: (MM)'},
#   {'name': 'T3',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Start date: (DD)'},
#   {'name': 'T4',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Start date: (YYYY)'},
#   {'name': 'CB5',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 2,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Continuation of therapy',
#    'on_state': 'Yes'},
#   {'name': 'T6',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Date of last treatment: (MM)'},
#   {'name': 'T7',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Date of last treatment: (DD)'},
#   {'name': 'T8',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Date of last treatment: (YYYY)'},
#   {'name': 'T9',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Precertification Requested By:'},
#   {'name': 'T10',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Phone:'},
#   {'name': 'T11',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Fax:'},
#   {'name': 'T12',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Patient First Name'},
#   {'name': 'T13',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Patient Last Name'},
#   {'name': 'T14',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Patient DOB (MM/DD/YYYY)'},
#   {'name': 'T15',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Address:'},
#   {'name': 'T16',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'City:'},
#   {'name': 'T17',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'State:'},
#   {'name': 'T18',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'ZIP:'},
#   {'name': 'T19',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Patient Phone'},
#   {'name': 'T20',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Work Phone:'},
#   {'name': 'T21',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Cell Phone:'},
#   {'name': 'T22',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'E-mail:'},
#   {'name': 'T24',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'lbs'},
#   {'name': 'T25',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'kgs'},
#   {'name': 'T26',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'inches'},
#   {'name': 'T27',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'cms'},
#   {'name': 'T23',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Allergies:'},
#   {'name': 'T28',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Member ID #:'},
#   {'name': 'T29',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Group #:'},
#   {'name': 'T30',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Insured:'},
#   {'name': 'CB31',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 2,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Yes',
#    'on_state': 'Yes'},
#   {'name': 'CB32',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 2,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'T33',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'If yes, provide ID#:'},
#   {'name': 'T34',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Carrier Name:'},
#   {'name': 'T35',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Insured:'},
#   {'name': 'T42',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'First Name:'},
#   {'name': 'T43',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Last Name:'},
#   {'name': 'CB44',
#    'type': 'checkbox',
#    'value': 'Yes',
#    'page': 2,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'M.D.',
#    'on_state': 'Yes'},
#   {'name': 'CB45',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 2,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'D.O.',
#    'on_state': 'Yes'},
#   {'name': 'CB46',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 2,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'N.P.',
#    'on_state': 'Yes'},
#   {'name': 'CB47',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 2,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'P.A.',
#    'on_state': 'Yes'},
#   {'name': 'T48',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Address:'},
#   {'name': 'T49',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'City:'},
#   {'name': 'T50',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'State:'},
#   {'name': 'T51',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'ZIP:'},
#   {'name': 'T52',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Phone:'},
#   {'name': 'T53',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Fax:'},
#   {'name': 'T54',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'St Lic #:'},
#   {'name': 'T55',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'NPI #:'},
#   {'name': 'T56',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'DEA #:'},
#   {'name': 'T57',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'UPIN:'},
#   {'name': 'T58.0',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Provider Email:'},
#   {'name': 'T58.1',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Office Contact Name:'},
#   {'name': 'T59',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Phone:'},
#   {'name': 'Provider Admin CB.1',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 2,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Self-administered',
#    'on_state': 'Yes'},
#   {'name': 'Provider Admin CB.2',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 2,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Physician’s Office',
#    'on_state': 'Yes'},
#   {'name': 'Provider Admin CB.3',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 2,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Home',
#    'on_state': 'Yes'},
#   {'name': 'Provider Admin CB.4',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 2,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Outpatient Infusion Center',
#    'on_state': 'Yes'},
#   {'name': 'Provider Admin T.5',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Name:'},
#   {'name': 'Provider Admin CB.7',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 2,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Home Infusion Center',
#    'on_state': 'Yes'},
#   {'name': 'Provider Admin T.6',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Phone:'},
#   {'name': 'Provider Admin T.8',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Agency Name:'},
#   {'name': 'Provider Admin CB.10',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 2,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Administration code(s)',
#    'on_state': 'Yes'},
#   {'name': 'Provider Admin T.9',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'CPT:'},
#   {'name': 'Provider Admin T.11A',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Address:'},
#   {'name': 'Provider Admin T.13',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'City:'},
#   {'name': 'Provider Admin T.14',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'State:'},
#   {'name': 'Provider Admin T.15',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'ZIP:'},
#   {'name': 'Provider Admin T.16',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Phone:'},
#   {'name': 'Provider Admin T.17A',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Fax:'},
#   {'name': 'Provider Admin T.18',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'TIN:'},
#   {'name': 'Provider Admin T.19',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'PIN:'},
#   {'name': 'Provider Admin T.20',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'NPI:'},
#   {'name': 'Provider Admin CB.21',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 2,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Outpatient Dialysis Center',
#    'on_state': 'Yes'},
#   {'name': 'Provider Admin CB.22',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 2,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Physician’s Office',
#    'on_state': 'Yes'},
#   {'name': 'Provider Admin CB.23.0.0',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 2,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Retail Pharmacy',
#    'on_state': 'Yes'},
#   {'name': 'Provider Admin CB.24.0.0',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 2,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Specialty Pharmacy',
#    'on_state': 'Yes'},
#   {'name': 'Provider Admin CB.25',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 2,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Mail Order',
#    'on_state': 'Yes'},
#   {'name': 'Provider Admin CB.26',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 2,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Other:',
#    'on_state': 'Yes'},
#   {'name': 'Provider Admin T.27',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Other:'},
#   {'name': 'Provider Admin T.28',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Name:'},
#   {'name': 'Provider Admin T.29a',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Address:'},
#   {'name': 'Provider Admin T.30a',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'City:'},
#   {'name': 'Provider Admin T.31',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'State:'},
#   {'name': 'Provider Admin T.32',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'ZIP:'},
#   {'name': 'Provider Admin T.33',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Phone:'},
#   {'name': 'Provider Admin T.34',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Fax:'},
#   {'name': 'Provider Admin T.35',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'TIN:'},
#   {'name': 'Provider Admin T.36',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'PIN:'},
#   {'name': 'Provider Admin T.37',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'NPI:'},
#   {'name': 'CB60',
#    'type': 'checkbox',
#    'value': '',
#    'page': 2,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Riabni (rituximab-arrx)',
#    'on_state': 'Yes'},
#   {'name': 'CB61',
#    'type': 'checkbox',
#    'value': '',
#    'page': 2,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Rituxan (rituximab)',
#    'on_state': 'Yes'},
#   {'name': 'CB62',
#    'type': 'checkbox',
#    'value': '',
#    'page': 2,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Ruxience (rituximab-pvvr)',
#    'on_state': 'Yes'},
#   {'name': 'CB63',
#    'type': 'checkbox',
#    'value': '',
#    'page': 2,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Truxima (rituximab-abbs)',
#    'on_state': 'Yes'},
#   {'name': 'T64',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Dose:'},
#   {'name': 'T65',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Directions for Use:'},
#   {'name': 'T66',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'HCPCS Code:'},
#   {'name': 'T67',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Primary ICD Code:'},
#   {'name': 'CB68',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 2,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Other ICD Code:',
#    'on_state': 'Yes'},
#   {'name': 'T69',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Other ICD Code:'},
#   {'name': 'CB70',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 2,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Yes',
#    'on_state': 'Yes'},
#   {'name': 'CB71',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 2,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'CB72',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 2,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'CB73',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 2,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Ruxience (rituximab-pvvr)',
#    'on_state': 'Yes'},
#   {'name': 'CB74',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 2,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Truxima (rituximab-abbs)',
#    'on_state': 'Yes'},
#   {'name': 'T75',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'When was the member’s trial and failure of the preferred drug?'},
#   {'name': 'T76',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Please describe the nature of the failure of the preferred drug'},
#   {'name': 'CB77',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 2,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'CB78',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 2,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Ruxience (rituximab-pvvr)',
#    'on_state': 'Yes'},
#   {'name': 'CB79',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 2,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Truxima (rituximab-abbs)',
#    'on_state': 'Yes'},
#   {'name': 'T80',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'When was the member’s adverse reaction to the preferred drug?'},
#   {'name': 'T81',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Please describe the nature of the adverse reaction to the preferred drug'},
#   {'name': 'T84',
#    'type': 'text',
#    'value': '',
#    'page': 2,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Please explain if there are any contraindications or other medical reason(s) that the patient cannot use any of the following preferred biosimilar products when indicated for the patient’s diagnosis?'},
#   {'name': 'CB82',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 2,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Ruxience (rituximab-pvvr)',
#    'on_state': 'Yes'},
#   {'name': 'CB83',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 2,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Truxima (rituximab-abbs)',
#    'on_state': 'Yes'}],
#  3: [{'name': 'T12',
#    'type': 'text',
#    'value': '',
#    'page': 3,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Patient First Name'},
#   {'name': 'T13',
#    'type': 'text',
#    'value': '',
#    'page': 3,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Patient Last Name'},
#   {'name': 'T19',
#    'type': 'text',
#    'value': '',
#    'page': 3,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Patient Phone'},
#   {'name': 'T14',
#    'type': 'text',
#    'value': '',
#    'page': 3,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Patient DOB (MM/DD/YYYY)'},
#   {'name': 'CB86',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Inflectra (infliximab-dyyb)',
#    'on_state': 'Yes'},
#   {'name': 'CB87',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Renflexis (infliximab-abda)',
#    'on_state': 'Yes'},
#   {'name': 'CB88',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Simponi Aria (golimumab)',
#    'on_state': 'Yes'},
#   {'name': 'T89',
#    'type': 'text',
#    'value': '',
#    'page': 3,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'When was the member’s trial and failure of the preferred drug?'},
#   {'name': 'T90',
#    'type': 'text',
#    'value': '',
#    'page': 3,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Please describe the nature of the failure of the preferred drug'},
#   {'name': 'CB85',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'CB92',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Inflectra (infliximab-dyyb)',
#    'on_state': 'Yes'},
#   {'name': 'CB93',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Renflexis (infliximab-abda)',
#    'on_state': 'Yes'},
#   {'name': 'CB94',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Simponi Aria (golimumab)',
#    'on_state': 'Yes'},
#   {'name': 'T95',
#    'type': 'text',
#    'value': '',
#    'page': 3,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'When was the member’s adverse reaction to the preferred drug?'},
#   {'name': 'T96a',
#    'type': 'text',
#    'value': '',
#    'page': 3,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Please describe the nature of the adverse reaction to the preferred drug'},
#   {'name': 'CB91',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'CB98a',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Enbrel (etanercept)',
#    'on_state': 'Yes'},
#   {'name': 'CB99a',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Humira (adalimumab)',
#    'on_state': 'Yes'},
#   {'name': 'CB100a',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Idacio (adalimumab-aacf)',
#    'on_state': 'Yes'},
#   {'name': 'CB101a',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Rinvoq (upadacitinib)',
#    'on_state': 'Yes'},
#   {'name': 'CB102a',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Tyenne SC (tocilizumab-aazg)',
#    'on_state': 'Yes'},
#   {'name': 'CB103a',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Xeljanz/Xeljanz XR (tofacitinib)',
#    'on_state': 'Yes'},
#   {'name': 'T104',
#    'type': 'text',
#    'value': '',
#    'page': 3,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'When was the member’s trial and failure of the preferred drug?'},
#   {'name': 'T105',
#    'type': 'text',
#    'value': '',
#    'page': 3,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Please describe the nature of the failure of the preferred drug'},
#   {'name': 'CB97',
#    'type': 'checkbox',
#    'value': '',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'CB107z',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Enbrel (etanercept)',
#    'on_state': 'Yes'},
#   {'name': 'CB108z',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Humira (adalimumab)',
#    'on_state': 'Yes'},
#   {'name': 'CB109z',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Idacio (adalimumab-aacf)',
#    'on_state': 'Yes'},
#   {'name': 'CB110z',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Rinvoq (upadacitinib)',
#    'on_state': 'Yes'},
#   {'name': 'CB111z',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Tyenne SC (tocilizumab-aazg)',
#    'on_state': 'Yes'},
#   {'name': 'CB112z',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Xeljanz/Xeljanz XR (tofacitinib)',
#    'on_state': 'Yes'},
#   {'name': 'T113',
#    'type': 'text',
#    'value': '',
#    'page': 3,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'When was the member’s adverse reaction to the preferred drug?'},
#   {'name': 'T114',
#    'type': 'text',
#    'value': '',
#    'page': 3,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Please describe the nature of the adverse reaction to the preferred drug'},
#   {'name': 'CB106z',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'T118',
#    'type': 'text',
#    'value': '',
#    'page': 3,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Please explain if there are any contraindications or other medical reason(s) that the patient cannot use any of the following preferred products when indicated for the patient’s diagnosis?'},
#   {'name': 'CB115z',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Inflectra (infliximab-dyyb)',
#    'on_state': 'Yes'},
#   {'name': 'CB116z',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Renflexis (infliximab-abda)',
#    'on_state': 'Yes'},
#   {'name': 'CB117z',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Simponi Aria (golimumab)',
#    'on_state': 'Yes'},
#   {'name': 'T125',
#    'type': 'text',
#    'value': '',
#    'page': 3,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Please explain if there are contraindications or any other medical reason(s) that the patient cannot use any of the following preferred products when indicated for the patient’s diagnosis?'},
#   {'name': 'CB119z',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Enbrel (etanercept)',
#    'on_state': 'Yes'},
#   {'name': 'CB120z',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Humira (adalimumab)',
#    'on_state': 'Yes'},
#   {'name': 'CB121z',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Idacio (adalimumab-aacf)',
#    'on_state': 'Yes'},
#   {'name': 'CB122z',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Rinvoq (upadacitinib)',
#    'on_state': 'Yes'},
#   {'name': 'CB123z',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Tyenne SC (tocilizumab-aazg)',
#    'on_state': 'Yes'},
#   {'name': 'CB124z',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Xeljanz/Xeljanz XR (tofacitinib)',
#    'on_state': 'Yes'},
#   {'name': 'CB96.4.0',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Yes',
#    'on_state': 'Yes'},
#   {'name': 'CB98',
#    'type': 'checkbox',
#    'value': '',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'CB99.0',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Yes',
#    'on_state': 'Yes'},
#   {'name': 'CB100.0',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'CB101.0',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Yes',
#    'on_state': 'Yes'},
#   {'name': 'CB102.0',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'CB103',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Yes',
#    'on_state': 'Yes'},
#   {'name': 'CB104',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'CB104a',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Wegener granulomatosis',
#    'on_state': 'Yes'},
#   {'name': 'CB104b',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Churg-Strauss syndrome',
#    'on_state': 'Yes'},
#   {'name': 'CB104c',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'microscopic polyangiitis',
#    'on_state': 'Yes'},
#   {'name': 'CB104d',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'pauci-immune glomerulonephritis',
#    'on_state': 'Yes'},
#   {'name': 'CB105',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Yes',
#    'on_state': 'Yes'},
#   {'name': 'CB106',
#    'type': 'checkbox',
#    'value': '',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'CB106a',
#    'type': 'checkbox',
#    'value': '',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Yes',
#    'on_state': 'Yes'},
#   {'name': 'CB107',
#    'type': 'checkbox',
#    'value': '',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'pemphigus vulgaris',
#    'on_state': 'Yes'},
#   {'name': 'CB108',
#    'type': 'checkbox',
#    'value': '',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'pemphigus folliaceus',
#    'on_state': 'Yes'},
#   {'name': 'CB109',
#    'type': 'checkbox',
#    'value': '',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'bullous pemphigoid',
#    'on_state': 'Yes'},
#   {'name': 'CB110',
#    'type': 'checkbox',
#    'value': '',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'cicatricial pemphigoid',
#    'on_state': 'Yes'},
#   {'name': 'CB111',
#    'type': 'checkbox',
#    'value': '',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'epidermolysis bullosa acquisita',
#    'on_state': 'Yes'},
#   {'name': 'CB112',
#    'type': 'checkbox',
#    'value': '',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'paraneoplastic pemphigus',
#    'on_state': 'Yes'},
#   {'name': 'CB113',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'None of the above',
#    'on_state': 'Yes'},
#   {'name': 'CB106b',
#    'type': 'checkbox',
#    'value': '',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'CB114',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'AIDS-related B-cell lymphoma',
#    'on_state': 'Yes'},
#   {'name': 'CB115',
#    'type': 'checkbox',
#    'value': '',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Burkitt lymphoma',
#    'on_state': 'Yes'},
#   {'name': 'CB116',
#    'type': 'checkbox',
#    'value': '',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Diffuse large B-cell lymphoma',
#    'on_state': 'Yes'},
#   {'name': 'CB117',
#    'type': 'checkbox',
#    'value': '',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Follicular lymphoma',
#    'on_state': 'Yes'},
#   {'name': 'CB118',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Gastric MALT lymphoma',
#    'on_state': 'Yes'},
#   {'name': 'CB119',
#    'type': 'checkbox',
#    'value': '',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'High-grade B-Cell lymphoma',
#    'on_state': 'Yes'},
#   {'name': 'CB120',
#    'type': 'checkbox',
#    'value': '',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Mantle cell lymphoma',
#    'on_state': 'Yes'},
#   {'name': 'CB121',
#    'type': 'checkbox',
#    'value': '',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Nodal marginal zone lymphoma',
#    'on_state': 'Yes'},
#   {'name': 'CB122',
#    'type': 'checkbox',
#    'value': '',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Nongastric MALT lymphoma',
#    'on_state': 'Yes'},
#   {'name': 'CB123',
#    'type': 'checkbox',
#    'value': '',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Primary cutaneous B-cell lymphomas',
#    'on_state': 'Yes'},
#   {'name': 'CB124',
#    'type': 'checkbox',
#    'value': '',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Splenic marginal zone lymphoma',
#    'on_state': 'Yes'},
#   {'name': 'CB125',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 3,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Other:',
#    'on_state': 'Yes'},
#   {'name': 'T126',
#    'type': 'text',
#    'value': '',
#    'page': 3,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Other:'}],
#  4: [{'name': 'T12',
#    'type': 'text',
#    'value': '',
#    'page': 4,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Patient First Name'},
#   {'name': 'T13',
#    'type': 'text',
#    'value': '',
#    'page': 4,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Patient Last Name'},
#   {'name': 'T19',
#    'type': 'text',
#    'value': '',
#    'page': 4,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Patient Phone'},
#   {'name': 'T14',
#    'type': 'text',
#    'value': '',
#    'page': 4,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Patient DOB (MM/DD/YYYY)'},
#   {'name': 'CB127',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Yes',
#    'on_state': 'Yes'},
#   {'name': 'CB128',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'CB129',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'leptomeningeal metastases from lymphoma',
#    'on_state': 'Yes'},
#   {'name': 'CB130',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'primary CNS lymphoma',
#    'on_state': 'Yes'},
#   {'name': 'CB131',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'none of the above',
#    'on_state': 'Yes'},
#   {'name': 'CB132',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'chronic lymphocytic leukemia (CLL)',
#    'on_state': 'Yes'},
#   {'name': 'CB133',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'small lymphocytic leukemia',
#    'on_state': 'Yes'},
#   {'name': 'CB134',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'none of the above',
#    'on_state': 'Yes'},
#   {'name': 'CB135',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Yes',
#    'on_state': 'Yes'},
#   {'name': 'CB136',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'CB139',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Yes',
#    'on_state': 'Yes'},
#   {'name': 'CB140',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'CB144',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Yes',
#    'on_state': 'Yes'},
#   {'name': 'CB145',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'CB141',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'relapsed hairy cell leukemia',
#    'on_state': 'Yes'},
#   {'name': 'CB142',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'refractory hairy cell leukemia',
#    'on_state': 'Yes'},
#   {'name': 'CB143',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'none of the above',
#    'on_state': 'Yes'},
#   {'name': 'CB137',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Yes',
#    'on_state': 'Yes'},
#   {'name': 'CB146',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'heart transplant recipient',
#    'on_state': 'Yes'},
#   {'name': 'CB147',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'other solid organ transplant recipient',
#    'on_state': 'Yes'},
#   {'name': 'CB138',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'CB148',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Bavencio (avelumab)',
#    'on_state': 'Yes'},
#   {'name': 'CB149',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Imfinzi (durvalumab)',
#    'on_state': 'Yes'},
#   {'name': 'CB150',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Keytruda (pembrolizumab)',
#    'on_state': 'Yes'},
#   {'name': 'CB151',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Opdivo (nivolumab)',
#    'on_state': 'Yes'},
#   {'name': 'CB152',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Tecentriq (atezolizumab)',
#    'on_state': 'Yes'},
#   {'name': 'CB153',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Yervoy (ipilimumab)',
#    'on_state': 'Yes'},
#   {'name': 'CB154',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Other:',
#    'on_state': 'Yes'},
#   {'name': 'T155',
#    'type': 'text',
#    'value': '',
#    'page': 4,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Other:'},
#   {'name': 'CB156',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Yes',
#    'on_state': 'Yes'},
#   {'name': 'CB158',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'refractory immune thrombocytopenic purpura',
#    'on_state': 'Yes'},
#   {'name': 'CB159',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'idiopathic thrombocytopenic purpura (ITP)',
#    'on_state': 'Yes'},
#   {'name': 'CB157',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'CB160',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Yes',
#    'on_state': 'Yes'},
#   {'name': 'CB161',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'CB162',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Yes',
#    'on_state': 'Yes'},
#   {'name': 'CB163',
#    'type': 'checkbox',
#    'value': 'Off',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'CB164',
#    'type': 'checkbox',
#    'value': '',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Relapsing-remitting MS (RRMS)',
#    'on_state': 'Yes'},
#   {'name': 'CB165',
#    'type': 'checkbox',
#    'value': '',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Secondary-progressive MS (SPMS)',
#    'on_state': 'Yes'},
#   {'name': 'CB166',
#    'type': 'checkbox',
#    'value': '',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Primary-progressive MS (PPMS)',
#    'on_state': 'Yes'},
#   {'name': 'CB167',
#    'type': 'checkbox',
#    'value': '',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Progressive-relapsing MS (PRMS)',
#    'on_state': 'Yes'},
#   {'name': 'CB168',
#    'type': 'checkbox',
#    'value': '',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Yes',
#    'on_state': 'Yes'},
#   {'name': 'CB169',
#    'type': 'checkbox',
#    'value': '',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'CB170',
#    'type': 'checkbox',
#    'value': '',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Yes',
#    'on_state': 'Yes'},
#   {'name': 'CB172',
#    'type': 'checkbox',
#    'value': '',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Yes',
#    'on_state': 'Yes'},
#   {'name': 'CB173',
#    'type': 'checkbox',
#    'value': '',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'CB171',
#    'type': 'checkbox',
#    'value': '',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'CB174',
#    'type': 'checkbox',
#    'value': '',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Yes',
#    'on_state': 'Yes'},
#   {'name': 'CB175',
#    'type': 'checkbox',
#    'value': '',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'CB176',
#    'type': 'checkbox',
#    'value': '',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Yes',
#    'on_state': 'Yes'},
#   {'name': 'CB177',
#    'type': 'checkbox',
#    'value': '',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'CB178',
#    'type': 'checkbox',
#    'value': '',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Yes',
#    'on_state': 'Yes'},
#   {'name': 'CB179',
#    'type': 'checkbox',
#    'value': '',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'CB180',
#    'type': 'checkbox',
#    'value': '',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Yes',
#    'on_state': 'Yes'},
#   {'name': 'T189',
#    'type': 'text',
#    'value': '',
#    'page': 4,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Medication:'},
#   {'name': 'T190',
#    'type': 'text',
#    'value': '',
#    'page': 4,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Date: (MM)'},
#   {'name': 'T191',
#    'type': 'text',
#    'value': '',
#    'page': 4,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Date: (DD)'},
#   {'name': 'T192',
#    'type': 'text',
#    'value': '',
#    'page': 4,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Date: (YYYY)'},
#   {'name': 'T193',
#    'type': 'text',
#    'value': '',
#    'page': 4,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Date: (MM)'},
#   {'name': 'T194',
#    'type': 'text',
#    'value': '',
#    'page': 4,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Date: (DD)'},
#   {'name': 'T195',
#    'type': 'text',
#    'value': '',
#    'page': 4,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Date: (YYYY)'},
#   {'name': 'T196',
#    'type': 'text',
#    'value': '',
#    'page': 4,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Medication:'},
#   {'name': 'T197',
#    'type': 'text',
#    'value': '',
#    'page': 4,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Date: (MM)'},
#   {'name': 'T198',
#    'type': 'text',
#    'value': '',
#    'page': 4,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Date: (DD)'},
#   {'name': 'T199',
#    'type': 'text',
#    'value': '',
#    'page': 4,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Date: (YYYY)'},
#   {'name': 'T200',
#    'type': 'text',
#    'value': '',
#    'page': 4,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Date: (MM)'},
#   {'name': 'T201',
#    'type': 'text',
#    'value': '',
#    'page': 4,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Date: (DD)'},
#   {'name': 'T202',
#    'type': 'text',
#    'value': '',
#    'page': 4,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Date: (YYYY)'},
#   {'name': 'CB181',
#    'type': 'checkbox',
#    'value': '',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'CB203',
#    'type': 'checkbox',
#    'value': '',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Yes',
#    'on_state': 'Yes'},
#   {'name': 'CB204',
#    'type': 'checkbox',
#    'value': '',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'CB205',
#    'type': 'checkbox',
#    'value': '',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Yes',
#    'on_state': 'Yes'},
#   {'name': 'CB206',
#    'type': 'checkbox',
#    'value': '',
#    'page': 4,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'}],
#  5: [{'name': 'T12',
#    'type': 'text',
#    'value': '',
#    'page': 5,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Patient First Name'},
#   {'name': 'T13',
#    'type': 'text',
#    'value': '',
#    'page': 5,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Patient Last Name'},
#   {'name': 'T19',
#    'type': 'text',
#    'value': '',
#    'page': 5,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Patient Phone'},
#   {'name': 'T14',
#    'type': 'text',
#    'value': '',
#    'page': 5,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Patient DOB (MM/DD/YYYY)'},
#   {'name': 'CB207',
#    'type': 'checkbox',
#    'value': '',
#    'page': 5,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Mild',
#    'on_state': 'Yes'},
#   {'name': 'CB208',
#    'type': 'checkbox',
#    'value': '',
#    'page': 5,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Moderate',
#    'on_state': 'Yes'},
#   {'name': 'CB209',
#    'type': 'checkbox',
#    'value': '',
#    'page': 5,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Severe',
#    'on_state': 'Yes'},
#   {'name': 'CB210',
#    'type': 'checkbox',
#    'value': '',
#    'page': 5,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Yes',
#    'on_state': 'Yes'},
#   {'name': 'CB211',
#    'type': 'checkbox',
#    'value': '',
#    'page': 5,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'CB212',
#    'type': 'checkbox',
#    'value': '',
#    'page': 5,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Yes',
#    'on_state': 'Yes'},
#   {'name': 'CB213',
#    'type': 'checkbox',
#    'value': '',
#    'page': 5,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'CB214',
#    'type': 'checkbox',
#    'value': '',
#    'page': 5,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Yes',
#    'on_state': 'Yes'},
#   {'name': 'CB216',
#    'type': 'checkbox',
#    'value': '',
#    'page': 5,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'ineffective',
#    'on_state': 'Yes'},
#   {'name': 'CB217',
#    'type': 'checkbox',
#    'value': '',
#    'page': 5,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'not tolerated',
#    'on_state': 'Yes'},
#   {'name': 'CB218',
#    'type': 'checkbox',
#    'value': '',
#    'page': 5,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'contraindicated',
#    'on_state': 'Yes'},
#   {'name': 'CB215',
#    'type': 'checkbox',
#    'value': '',
#    'page': 5,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'CB223',
#    'type': 'checkbox',
#    'value': '',
#    'page': 5,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Yes',
#    'on_state': 'Yes'},
#   {'name': 'CB225',
#    'type': 'checkbox',
#    'value': '',
#    'page': 5,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'azathioprine',
#    'on_state': 'Yes'},
#   {'name': 'CB226',
#    'type': 'checkbox',
#    'value': '',
#    'page': 5,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'cyclosporine',
#    'on_state': 'Yes'},
#   {'name': 'CB227',
#    'type': 'checkbox',
#    'value': '',
#    'page': 5,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'hydroxychloroquine',
#    'on_state': 'Yes'},
#   {'name': 'CB228',
#    'type': 'checkbox',
#    'value': '',
#    'page': 5,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'leflunomide',
#    'on_state': 'Yes'},
#   {'name': 'CB229',
#    'type': 'checkbox',
#    'value': '',
#    'page': 5,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'sulfasalazine',
#    'on_state': 'Yes'},
#   {'name': 'CB224',
#    'type': 'checkbox',
#    'value': '',
#    'page': 5,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'CB281',
#    'type': 'checkbox',
#    'value': '',
#    'page': 5,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Yes',
#    'on_state': 'Yes'},
#   {'name': 'CB282',
#    'type': 'checkbox',
#    'value': '',
#    'page': 5,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'CB283',
#    'type': 'checkbox',
#    'value': '',
#    'page': 5,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Yes',
#    'on_state': 'Yes'},
#   {'name': 'T285',
#    'type': 'text',
#    'value': '',
#    'page': 5,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Medication:'},
#   {'name': 'T286',
#    'type': 'text',
#    'value': '',
#    'page': 5,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Date: (MM)'},
#   {'name': 'T287',
#    'type': 'text',
#    'value': '',
#    'page': 5,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Date: (DD)'},
#   {'name': 'T288',
#    'type': 'text',
#    'value': '',
#    'page': 5,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Date: (YYYY)'},
#   {'name': 'T289',
#    'type': 'text',
#    'value': '',
#    'page': 5,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Date: (MM)'},
#   {'name': 'T290',
#    'type': 'text',
#    'value': '',
#    'page': 5,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Date: (DD)'},
#   {'name': 'T291',
#    'type': 'text',
#    'value': '',
#    'page': 5,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Date: (YYYY)'},
#   {'name': 'T292',
#    'type': 'text',
#    'value': '',
#    'page': 5,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Medication:'},
#   {'name': 'T293',
#    'type': 'text',
#    'value': '',
#    'page': 5,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Date: (MM)'},
#   {'name': 'T294',
#    'type': 'text',
#    'value': '',
#    'page': 5,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Date: (DD)'},
#   {'name': 'T295',
#    'type': 'text',
#    'value': '',
#    'page': 5,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Date: (YYYY)'},
#   {'name': 'T296',
#    'type': 'text',
#    'value': '',
#    'page': 5,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Date: (MM)'},
#   {'name': 'T297',
#    'type': 'text',
#    'value': '',
#    'page': 5,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Date: (DD)'},
#   {'name': 'T298',
#    'type': 'text',
#    'value': '',
#    'page': 5,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Date: (YYYY)'},
#   {'name': 'CB284',
#    'type': 'checkbox',
#    'value': '',
#    'page': 5,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'CB299',
#    'type': 'checkbox',
#    'value': '',
#    'page': 5,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Yes',
#    'on_state': 'Yes'},
#   {'name': 'CB300',
#    'type': 'checkbox',
#    'value': '',
#    'page': 5,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'CB301',
#    'type': 'checkbox',
#    'value': '',
#    'page': 5,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Yes',
#    'on_state': 'Yes'},
#   {'name': 'CB302',
#    'type': 'checkbox',
#    'value': '',
#    'page': 5,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'CB303',
#    'type': 'checkbox',
#    'value': '',
#    'page': 5,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Yes',
#    'on_state': 'Yes'},
#   {'name': 'CB304',
#    'type': 'checkbox',
#    'value': '',
#    'page': 5,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'T305',
#    'type': 'text',
#    'value': '',
#    'page': 5,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Please indicate the length of time on Rituxan (rituximab):'},
#   {'name': 'CB310',
#    'type': 'checkbox',
#    'value': '',
#    'page': 5,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Mild',
#    'on_state': 'Yes'},
#   {'name': 'CB311',
#    'type': 'checkbox',
#    'value': '',
#    'page': 5,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Moderate',
#    'on_state': 'Yes'},
#   {'name': 'CB312',
#    'type': 'checkbox',
#    'value': '',
#    'page': 5,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Severe',
#    'on_state': 'Yes'},
#   {'name': 'CB306',
#    'type': 'checkbox',
#    'value': '',
#    'page': 5,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Yes',
#    'on_state': 'Yes'},
#   {'name': 'CB307',
#    'type': 'checkbox',
#    'value': '',
#    'page': 5,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'CB308',
#    'type': 'checkbox',
#    'value': '',
#    'page': 5,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Yes',
#    'on_state': 'Yes'},
#   {'name': 'CB309',
#    'type': 'checkbox',
#    'value': '',
#    'page': 5,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'CB313',
#    'type': 'checkbox',
#    'value': '',
#    'page': 5,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Yes',
#    'on_state': 'Yes'},
#   {'name': 'CB314',
#    'type': 'checkbox',
#    'value': '',
#    'page': 5,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'CB315',
#    'type': 'checkbox',
#    'value': '',
#    'page': 5,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'Yes',
#    'on_state': 'Yes'},
#   {'name': 'CB316',
#    'type': 'checkbox',
#    'value': '',
#    'page': 5,
#    'field_type': 2,
#    'field_type_string': 'CheckBox',
#    'field_label': 'No',
#    'on_state': 'Yes'},
#   {'name': 'T317',
#    'type': 'text',
#    'value': '',
#    'page': 5,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Date: (MM)'},
#   {'name': 'T318',
#    'type': 'text',
#    'value': '',
#    'page': 5,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Date: (DD)'},
#   {'name': 'T319',
#    'type': 'text',
#    'value': '',
#    'page': 5,
#    'field_type': 7,
#    'field_type_string': 'Text',
#    'field_label': 'Date: (YYYY)'}]}

# %%
PROMPT_PA = """
You are an expert medical document processing assistant specializing in Prior Authorization (PA) form analysis and field mapping.
Your task is to process and enrich PA form field data with detailed contextual information.

Given Input:
1. A structured dataset containing PA form field definitions including:
   - Field names (e.g. CB1, T1)
   - Field types (checkbox, text, etc.)
   - Page numbers
   - Field labels
   - Current values

2. The complete Prior Authorization form PDF document

Required Processing:
For each form field, analyze sequentially by page number and:

1. Extract the implicit question being asked by the field:
   - For checkboxes: Rephrase the field_label into a yes/no question starting with "Is", "Does", or "Has".
   - For text fields: Frame as an information request.
   - For date fields: Specify what event/action the date refers to.

2. Generate rich contextual information that includes:
   - The section/category the field belongs to.
   - Whether it's a primary question or sub-question.
   - Whose information is being requested (patient, provider, insurer).
   - Any dependencies on other fields.
   - Clinical relevance of the requested information.

<CRITICAL_REQUIREMENTS>
- Every field must have both "question" and "context" added.
- Context must be specific and clinically relevant.
- Maintain logical relationships between fields.
- Preserve exact field names and field labels from the input.
- Keep context concise but informative (25 words max).
- Output must be a valid JSON array only.
- Do not include markdown formatting, triple backticks, or any extra commentary.
</CRITICAL_REQUIREMENTS>

<RESPONSE_FORMAT>
{{
  {{
    "name": "CB1",
    "type": "checkbox",
    "page": 2,
    "field_label": "Start of treatment",
    "question": "Is this a new treatment start for the patient?",
    "context": "Initial checkbox in treatment timeline section indicating whether patient is beginning new therapy versus continuing existing treatment."
  }},
  {{
    "name": "T2",
    "type": "text",
    "page": 2,
    "field_label": "Start date: (MM)",
    "question": "What is the month of treatment start?",
    "context": "2-digit month format for planned medication initiation date in treatment scheduling section."
  }}
}}
</RESPONSE_FORMAT>

<PA_FORM_DATA>
This is a JSON array of field definitions:
{page_fields}
</PA_FORM_DATA>

Return only the JSON array as described. Do not include any text outside the JSON array.
"""

# %%
async def query_gemini_async(prompt, pdf_path, model="gemini-2.5-flash"):
    import pathlib
    
    filepath = pathlib.Path(pdf_path)
    loop = asyncio.get_event_loop()
    
    # Configure model for JSON output
    generation_config = genai.GenerationConfig(
        response_mime_type="application/json"
    )
    
    response = await loop.run_in_executor(
        None,
        lambda: genai.GenerativeModel(
            model,
            generation_config=generation_config
        ).generate_content([
            genai.upload_file(path=filepath),
            prompt
        ])
    )
    
    return response.text

async def process_pa_fields_async(pa_fields_data, pdf_path):
    async def process_page(page_num, page_fields):
        prompt = PROMPT_PA.format(page_fields=json.dumps(page_fields))
        result = await query_gemini_async(prompt, pdf_path)
        return page_num, result
    
    # Create tasks for all pages
    tasks = [process_page(page, fields) for page, fields in pa_fields_data.items()]
    
    # Run all pages concurrently
    results = await asyncio.gather(*tasks)
    
    # Simple results structure
    enhanced_fields = {}
    for page, result in results:
        enhanced_fields[page] = result
        print(f"Page {page} processed")
    
    return enhanced_fields

# Usage
enhanced_pa_data = await process_pa_fields_async(abdulla_pa_fields, "Input Data/Abdulla/PA.pdf")
# Out:
# Page 2 processed
# Page 3 processed
# Page 4 processed
# Page 5 processed

# %%
enhanced_pa_data
# Out:
# {2: '[\n  {\n    "name": "CB1",\n    "type": "checkbox",\n    "value": "Off",\n    "page": 2,\n    "field_type": 2,\n    "field_type_string": "CheckBox",\n    "field_label": "Start of treatment",\n    "question": "Is this a new treatment start for the patient?",\n    "context": "Primary question in the treatment timeline section for new medication initiation. Patient information."\n  },\n  {\n    "name": "T2",\n    "type": "text",\n    "value": "",\n    "page": 2,\n    "field_type": 7,\n    "field_type_string": "Text",\n    "field_label": "Start date: (MM)",\n    "question": "What is the month of treatment start?",\n    "context": "Month of planned medication initiation date. Required if \'Start of treatment\' is selected. Patient information."\n  },\n  {\n    "name": "T3",\n    "type": "text",\n    "value": "",\n    "page": 2,\n    "field_type": 7,\n    "field_type_string": "Text",\n    "field_label": "Start date: (DD)",\n    "question": "What is the day of treatment start?",\n    "context": "Day of planned medication initiation date. Required if \'Start of treatment\' is selected. Patient information."\n  },\n  {\n    "name": "T4",\n    "type": "text",\n    "value": "",\n    "page": 2,\n    "field_type": 7,\n    "field_type_string": "Text",\n    "field_label": "Start date: (YYYY)",\n    "question": "What is the year of treatment start?",\n    "context": "Year of planned medication initiation date. Required if \'Start of treatment\' is selected. Patient information."\n  },\n  {\n    "name": "CB5",\n    "type": "checkbox",\n    "value": "Off",\n    "page": 2,\n    "field_type": 2,\n    "field_type_string": "CheckBox",\n    "field_label": "Continuation of therapy",\n    "question": "Is this a continuation of existing therapy?",\n    "context": "Primary question in the treatment timeline section for ongoing medication therapy. Patient information."\n  },\n  {\n    "name": "T6",\n    "type": "text",\n    "value": "",\n    "page": 2,\n    "field_type": 7,\n    "field_type_string": "Text",\n    "field_label": "Date of last treatment: (MM)",\n    "question": "What is the month of the last treatment date?",\n    "context": "Month of patient\'s last medication administration. Required if \'Continuation of therapy\' is selected. Patient information."\n  },\n  {\n    "name": "T7",\n    "type": "text",\n    "value": "",\n    "page": 2,\n    "field_type": 7,\n    "field_type_string": "Text",\n    "field_label": "Date of last treatment: (DD)",\n    "question": "What is the day of the last treatment date?",\n    "context": "Day of patient\'s last medication administration. Required if \'Continuation of therapy\' is selected. Patient information."\n  },\n  {\n    "name": "T8",\n    "type": "text",\n    "value": "",\n    "page": 2,\n    "field_type": 7,\n    "field_type_string": "Text",\n    "field_label": "Date of last treatment: (YYYY)",\n    "question": "What is the year of the last treatment date?",\n    "context": "Year of patient\'s last medication administration. Required if \'Continuation of therapy\' is selected. Patient information."\n  },\n  {\n    "name": "T9",\n    "type": "text",\n    "value": "",\n    "page": 2,\n    "field_type": 7,\n    "field_type_string": "Text",\n    "field_label": "Precertification Requested By:",\n    "question": "Please provide the name of the person requesting precertification.",\n    "context": "Required contact information for the individual submitting the prior authorization request. Requestor information."\n  },\n  {\n    "name": "T10",\n    "type": "text",\n    "value": "",\n    "page": 2,\n    "field_type": 7,\n    "field_type_string": "Text",\n    "field_label": "Phone:",\n    "question": "What is the phone number of the requestor?",\n    "context": "Contact phone number for the individual submitting the prior authorization request. Requestor information."\n  },\n  {\n    "name": "T11",\n    "type": "text",\n    "value": "",\n    "page": 2,\n    "field_type": 7,\n    "field_type_string": "Text", ...
#  3: '[\n  {\n    "name": "T12",\n    "type": "text",\n    "value": "",\n    "page": 3,\n    "field_type": 7,\n    "field_type_string": "Text",\n    "field_label": "Patient First Name",\n    "question": "What is the patient\'s first name?",\n    "context": "Basic demographic information for patient identification in the Patient Information section."\n  },\n  {\n    "name": "T13",\n    "type": "text",\n    "value": "",\n    "page": 3,\n    "field_type": 7,\n    "field_type_string": "Text",\n    "field_label": "Patient Last Name",\n    "question": "What is the patient\'s last name?",\n    "context": "Basic demographic information for patient identification in the Patient Information section."\n  },\n  {\n    "name": "T19",\n    "type": "text",\n    "value": "",\n    "page": 3,\n    "field_type": 7,\n    "field_type_string": "Text",\n    "field_label": "Patient Phone",\n    "question": "What is the patient\'s phone number?",\n    "context": "Contact information for the patient in the Patient Information section."\n  },\n  {\n    "name": "T14",\n    "type": "text",\n    "value": "",\n    "page": 3,\n    "field_type": 7,\n    "field_type_string": "Text",\n    "field_label": "Patient DOB (MM/DD/YYYY)",\n    "question": "What is the patient\'s date of birth?",\n    "context": "Full date of birth for patient identification and age verification in the Patient Information section."\n  },\n  {\n    "name": "CB86",\n    "type": "checkbox",\n    "value": "Off",\n    "page": 3,\n    "field_type": 2,\n    "field_type_string": "CheckBox",\n    "field_label": "Inflectra (infliximab-dyyb)",\n    "on_state": "Yes",\n    "question": "Has the patient had a trial and failure of Inflectra (infliximab-dyyb)?",\n    "context": "Indicates prior trial and failure of a specific infliximab biosimilar, informing therapy selection."\n  },\n  {\n    "name": "CB87",\n    "type": "checkbox",\n    "value": "Off",\n    "page": 3,\n    "field_type": 2,\n    "field_type_string": "CheckBox",\n    "field_label": "Renflexis (infliximab-abda)",\n    "on_state": "Yes",\n    "question": "Has the patient had a trial and failure of Renflexis (infliximab-abda)?",\n    "context": "Indicates prior trial and failure of a specific infliximab biosimilar, informing therapy selection."\n  },\n  {\n    "name": "CB88",\n    "type": "checkbox",\n    "value": "Off",\n    "page": 3,\n    "field_type": 2,\n    "field_type_string": "CheckBox",\n    "field_label": "Simponi Aria (golimumab)",\n    "on_state": "Yes",\n    "question": "Has the patient had a trial and failure of Simponi Aria (golimumab)?",\n    "context": "Indicates prior trial and failure of a specific golimumab biologic, informing therapy selection."\n  },\n  {\n    "name": "T89",\n    "type": "text",\n    "value": "",\n    "page": 3,\n    "field_type": 7,\n    "field_type_string": "Text",\n    "field_label": "When was the member\\u2019s trial and failure of the preferred drug?",\n    "question": "What was the date of the member\'s trial and failure of the preferred drug?",\n    "context": "Date of trial and failure for preferred drug, required if patient had prior therapy with listed drugs."\n  },\n  {\n    "name": "T90",\n    "type": "text",\n    "value": "",\n    "page": 3,\n    "field_type": 7,\n    "field_type_string": "Text",\n    "field_label": "Please describe the nature of the failure of the preferred drug",\n    "question": "Please describe the nature of the failure of the preferred drug.",\n    "context": "Detailed explanation of why the prior preferred therapy failed, for clinical justification."\n  },\n  {\n    "name": "CB85",\n    "type": "checkbox",\n    "value": "Off",\n    "page": 3,\n    "field_type": 2,\n    "field_type_string": "CheckBox",\n    "field_label": "No",\n    "on_state": "Yes",\n    "question": "Has the patient not had a trial and failure of any of the specified infliximab/golimumab biosimilars?",\n    "context": "Indicates absence of prior trial and failure with specified biologics, influenci ...
#  4: '[\n  {\n    "name": "T12",\n    "type": "text",\n    "page": 4,\n    "field_type": 7,\n    "field_type_string": "Text",\n    "field_label": "Patient First Name",\n    "question": "What is the patient\'s first name?",\n    "context": "Patient information section, mandatory for identification. This is a primary field."\n  },\n  {\n    "name": "T13",\n    "type": "text",\n    "page": 4,\n    "field_type": 7,\n    "field_type_string": "Text",\n    "field_label": "Patient Last Name",\n    "question": "What is the patient\'s last name?",\n    "context": "Patient information section, mandatory for identification. This is a primary field."\n  },\n  {\n    "name": "T19",\n    "type": "text",\n    "page": 4,\n    "field_type": 7,\n    "field_type_string": "Text",\n    "field_label": "Patient Phone",\n    "question": "What is the patient\'s phone number?",\n    "context": "Patient contact information for communication. This is a primary field."\n  },\n  {\n    "name": "T14",\n    "type": "text",\n    "page": 4,\n    "field_type": 7,\n    "field_type_string": "Text",\n    "field_label": "Patient DOB (MM/DD/YYYY)",\n    "question": "What is the patient\'s date of birth (MM/DD/YYYY)?",\n    "context": "Patient demographic information, essential for eligibility and identification. This is a primary field."\n  },\n  {\n    "name": "CB127",\n    "type": "checkbox",\n    "value": "Off",\n    "page": 4,\n    "field_type": 2,\n    "field_type_string": "CheckBox",\n    "field_label": "Yes",\n    "on_state": "Yes",\n    "question": "Does the patient have a documented diagnosis of multicentric Castleman\'s disease (angiofollicular lymph node hyperplasia)?",\n    "context": "Clinical information for Castleman\'s disease. Primary question to determine medical necessity for therapy."\n  },\n  {\n    "name": "CB128",\n    "type": "checkbox",\n    "value": "Off",\n    "page": 4,\n    "field_type": 2,\n    "field_type_string": "CheckBox",\n    "field_label": "No",\n    "on_state": "Yes",\n    "question": "Does the patient not have a documented diagnosis of multicentric Castleman\'s disease (angiofollicular lymph node hyperplasia)?",\n    "context": "Clinical information for Castleman\'s disease. Primary question to determine medical necessity for therapy."\n  },\n  {\n    "name": "CB129",\n    "type": "checkbox",\n    "value": "Off",\n    "page": 4,\n    "field_type": 2,\n    "field_type_string": "CheckBox",\n    "field_label": "leptomeningeal metastases from lymphoma",\n    "on_state": "Yes",\n    "question": "Is the patient\'s central nervous system lymphoma characterized by leptomeningeal metastases from lymphoma?",\n    "context": "Specific diagnosis detail for Central Nervous System Lymphomas. Affects treatment criteria and medical necessity."\n  },\n  {\n    "name": "CB130",\n    "type": "checkbox",\n    "value": "Off",\n    "page": 4,\n    "field_type": 2,\n    "field_type_string": "CheckBox",\n    "field_label": "primary CNS lymphoma",\n    "on_state": "Yes",\n    "question": "Is the patient\'s central nervous system lymphoma a primary CNS lymphoma?",\n    "context": "Specific diagnosis detail for Central Nervous System Lymphomas. Affects treatment criteria and medical necessity."\n  },\n  {\n    "name": "CB131",\n    "type": "checkbox",\n    "value": "Off",\n    "page": 4,\n    "field_type": 2,\n    "field_type_string": "CheckBox",\n    "field_label": "none of the above",\n    "on_state": "Yes",\n    "question": "Is the patient\'s central nervous system lymphoma not any of the specified types?",\n    "context": "Indicates if the patient\'s CNS lymphoma type does not fit the provided options, requiring further clarification."\n  },\n  {\n    "name": "CB132",\n    "type": "checkbox",\n    "value": "Off",\n    "page": 4,\n    "field_type": 2,\n    "field_type_string": "CheckBox",\n    "field_label": "chronic lymphocytic leukemia (CLL)",\n    "on_state": "Yes",\n    "question": "Is the patient\'s leukemia chronic lymphocytic leukemia (CLL)?",\n  ...
#  5: '[\n  {\n    "name": "T12",\n    "type": "text",\n    "value": "",\n    "page": 5,\n    "field_type": 7,\n    "field_type_string": "Text",\n    "field_label": "Patient First Name",\n    "question": "What is the patient\'s first name?",\n    "context": "Patient demographic information for identification purposes in Section G. Clinical Information."\n  },\n  {\n    "name": "T13",\n    "type": "text",\n    "value": "",\n    "page": 5,\n    "field_type": 7,\n    "field_type_string": "Text",\n    "field_label": "Patient Last Name",\n    "question": "What is the patient\'s last name?",\n    "context": "Patient demographic information for identification purposes in Section G. Clinical Information."\n  },\n  {\n    "name": "T19",\n    "type": "text",\n    "value": "",\n    "page": 5,\n    "field_type": 7,\n    "field_type_string": "Text",\n    "field_label": "Patient Phone",\n    "question": "What is the patient\'s phone number?",\n    "context": "Patient contact information for communication purposes in Section G. Clinical Information."\n  },\n  {\n    "name": "T14",\n    "type": "text",\n    "value": "",\n    "page": 5,\n    "field_type": 7,\n    "field_type_string": "Text",\n    "field_label": "Patient DOB (MM/DD/YYYY)",\n    "question": "What is the patient\'s date of birth?",\n    "context": "Patient demographic information for identification and age verification in Section G. Clinical Information."\n  },\n  {\n    "name": "CB207",\n    "type": "checkbox",\n    "value": "",\n    "page": 5,\n    "field_type": 2,\n    "field_type_string": "CheckBox",\n    "field_label": "Mild",\n    "on_state": "Yes",\n    "question": "Is the patient\'s rheumatoid arthritis mild?",\n    "context": "Severity assessment of rheumatoid arthritis at baseline, crucial for treatment justification in Section G."\n  },\n  {\n    "name": "CB208",\n    "type": "checkbox",\n    "value": "",\n    "page": 5,\n    "field_type": 2,\n    "field_type_string": "CheckBox",\n    "field_label": "Moderate",\n    "on_state": "Yes",\n    "question": "Is the patient\'s rheumatoid arthritis moderate?",\n    "context": "Severity assessment of rheumatoid arthritis at baseline, crucial for treatment justification in Section G."\n  },\n  {\n    "name": "CB209",\n    "type": "checkbox",\n    "value": "",\n    "page": 5,\n    "field_type": 2,\n    "field_type_string": "CheckBox",\n    "field_label": "Severe",\n    "on_state": "Yes",\n    "question": "Is the patient\'s rheumatoid arthritis severe?",\n    "context": "Severity assessment of rheumatoid arthritis at baseline, crucial for treatment justification in Section G."\n  },\n  {\n    "name": "CB210",\n    "type": "checkbox",\n    "value": "",\n    "page": 5,\n    "field_type": 2,\n    "field_type_string": "CheckBox",\n    "field_label": "Yes",\n    "on_state": "Yes",\n    "question": "Is there evidence that the patient\'s rheumatoid arthritis disease is active?",\n    "context": "Confirms active disease state for treatment necessity. Sub-question to RA severity in Section G."\n  },\n  {\n    "name": "CB211",\n    "type": "checkbox",\n    "value": "",\n    "page": 5,\n    "field_type": 2,\n    "field_type_string": "CheckBox",\n    "field_label": "No",\n    "on_state": "Yes",\n    "question": "Is there no evidence that the patient\'s rheumatoid arthritis disease is active?",\n    "context": "Confirms inactive disease state for treatment necessity. Sub-question to RA severity in Section G."\n  },\n  {\n    "name": "CB212",\n    "type": "checkbox",\n    "value": "",\n    "page": 5,\n    "field_type": 2,\n    "field_type_string": "CheckBox",\n    "field_label": "Yes",\n    "on_state": "Yes",\n    "question": "Will Rituxan (rituximab) be used in combination with methotrexate?",\n    "context": "Inquires about concomitant therapy for rheumatoid arthritis, affecting treatment efficacy. Primary question in Section G."\n  },\n  {\n    "name": "CB213",\n    "type": "checkbox",\n    "value": "",\n    "page": 5,\n    "field_type": 2,\n  ...
